# %%
data = """Con diez cañones por banda,
viento en popa a toda vela,
no corta el mar, sino vuela,
un velero bergantín;
bajel pirata que llaman
por su bravura el Temido
en todo el mar conocido
del uno al otro confín.
La luna en el mar riela,
en la lona gime el viento
y alza en blando movimiento
olas de plata y azul;
y ve el capitán pirata,
cantando alegre en la popa,
Asia a un lado, al otro Europa,
Y allá a su frente Estambul:
-Navega, velero mío,
sin temor
que ni enemigo navío,
ni tormenta, ni bonanza
tu rumbo a torcer alcanza,
ni a sujetar tu valor.
Veinte presas
hemos hecho
a despecho
del inglés
y han rendido
sus pendones
cien naciones
a mis pies.
Que es mi barco mi tesoro,
que es mi Dios la libertad;
mi ley, la fuerza y el viento;
mi única patria, la mar.
Allá muevan feroz guerra
ciegos reyes
por un palmo más de tierra,
que yo tengo aquí por mío
cuanto abarca el mar bravío
a quien nadie impuso leyes.
Y no hay playa
sea cualquiera,
ni bandera
de esplendor,
que no sienta
mi derecho
y dé pecho
a mi valor
Que es mi barco mi tesoro,
que es mi Dios la libertad;
mi ley, la fuerza y el viento;
mi única patria, la mar.
A la voz de ¡barco viene!,
es de ver
cómo vira y se previene
a todo trapo a escapar:
que yo soy el rey del mar
y mi furia es de temer.
En las presas
yo divido
lo cogido
por igual:
sólo quiero
por riqueza
la belleza
sin rival.
Que es mi barco mi tesoro,
que es mi Dios la libertad;
mi ley, la fuerza y el viento;
mi única patria, la mar.
¡Sentenciado estoy a muerte!
Yo me río:
no me abandone la suerte,
y al mismo que me condena
colgaré de alguna antena
quizá en su propio navío.
Y si caigo,
¿qué es la vida?
Por perdida
ya la di
cuando el yugo
del esclavo
como un bravo sacudí.
Que es mi barco mi tesoro,
que es mi Dios la libertad;
mi ley, la fuerza y el viento;
mi única patria, la mar.
Son mi música mejor
aquilones,
el estrépito y temblor
de los cables sacudidos
del negro mar los bramidos
y el rugir de mis cañones.
Y del trueno
al son violento,
y del viento,
al rebramar,
yo me duermo
sosegado,
arrullado
por el mar.
Que es mi barco mi tesoro,
que es mi Dios la libertad;
mi ley, la fuerza y el viento;
mi única patria, la mar."""

# %%
# Need to update CUDA in order to use GPU, so I disable this
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
from src.model import BaseNetwork
# Out:
# Using TensorFlow backend.

# %%
def print_shapes():
    print(f"Shape of X_train: {X_train.shape}")
    print(f"Shape of X_test: {X_test.shape}")
    print(f"Shape of y_train: {y_train.shape}")
    print(f"Shape of y_test: {y_test.shape}")

# %%
model = BaseNetwork()
X_train, X_test, y_train, y_test = model.etl(data)
print_shapes()
model.fit(X_train, X_test, y_train, y_test, arch="Baseline", epochs=200, verbose=2, batch_size=32)
# Out:
# Shape of X_train: (247, 6)
# Shape of X_test: (82, 6)
# Shape of y_train: (247, 194)
# Shape of y_test: (82, 194)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 6, 64)             12416
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 194)               74690
# =================================================================
# Total params: 87,106
# Trainable params: 87,106
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 247 samples, validate on 82 samples
# Epoch 1/200
#  - 0s - loss: 5.2510 - perplexity_raw: 1.3339 - val_loss: 5.2360 - val_perplexity_raw: 1.5448
# Epoch 2/200
#  - 0s - loss: 5.1819 - perplexity_raw: 1.5009 - val_loss: 5.2152 - val_perplexity_raw: 1.4610
# Epoch 3/200
#  - 0s - loss: 5.1098 - perplexity_raw: 1.4870 - val_loss: 5.1930 - val_perplexity_raw: 1.4400
# Epoch 4/200
#  - 0s - loss: 5.0239 - perplexity_raw: 1.4522 - val_loss: 5.1680 - val_perplexity_raw: 1.4400
# Epoch 5/200
#  - 0s - loss: 4.9137 - perplexity_raw: 1.4383 - val_loss: 5.1451 - val_perplexity_raw: 1.4400
# Epoch 6/200
#  - 0s - loss: 4.7865 - perplexity_raw: 1.4452 - val_loss: 5.1259 - val_perplexity_raw: 1.3772
# Epoch 7/200
#  - 0s - loss: 4.6444 - perplexity_raw: 1.4174 - val_loss: 5.1148 - val_perplexity_raw: 1.3143
# Epoch 8/200
#  - 0s - loss: 4.4900 - perplexity_raw: 1.3965 - val_loss: 5.1182 - val_perplexity_raw: 1.3143
# Epoch 9/200
#  - 0s - loss: 4.3360 - perplexity_raw: 1.3965 - val_loss: 5.1362 - val_perplexity_raw: 1.3143
# Epoch 10/200
#  - 0s - loss: 4.1905 - perplexity_raw: 1.3409 - val_loss: 5.1665 - val_perplexity_raw: 1.2724
# Epoch 11/200
#  - 0s - loss: 4.0586 - perplexity_raw: 1.3200 - val_loss: 5.2055 - val_perplexity_raw: 1.2934
# Epoch 12/200
#  - 0s - loss: 3.9246 - perplexity_raw: 1.2991 - val_loss: 5.2404 - val_perplexity_raw: 1.1886
# Epoch 13/200
#  - 0s - loss: 3.8083 - perplexity_raw: 1.1878 - val_loss: 5.2619 - val_perplexity_raw: 1.1257
# Epoch 14/200
#  - 0s - loss: 3.6823 - perplexity_raw: 1.1530 - val_loss: 5.2727 - val_perplexity_raw: 1.1257
# Epoch 15/200
#  - 0s - loss: 3.5583 - perplexity_raw: 1.1600 - val_loss: 5.2754 - val_perplexity_raw: 1.1257
# Epoch 16/200
#  - 0s - loss: 3.4260 - perplexity_raw: 1.1530 - val_loss: 5.2732 - val_perplexity_raw: 1.1257
# Epoch 17/200
#  - 0s - loss: 3.2945 - perplexity_raw: 1.1391 - val_loss: 5.2689 - val_perplexity_raw: 1.1257
# Epoch 18/200
#  - 0s - loss: 3.1628 - perplexity_raw: 1.1809 - val_loss: 5.2621 - val_perplexity_raw: 1.1676
# Epoch 19/200
#  - 0s - loss: 3.0312 - perplexity_raw: 1.1739 - val_loss: 5.2611 - val_perplexity_raw: 1.1257
# Epoch 20/200
#  - 0s - loss: 2.9028 - perplexity_raw: 1.1530 - val_loss: 5.2583 - val_perplexity_raw: 1.1467
# Epoch 21/200
#  - 0s - loss: 2.7786 - perplexity_raw: 1.1461 - val_loss: 5.2698 - val_perplexity_raw: 1.1467
# Epoch 22/200
#  - 0s - loss: 2.6565 - perplexity_raw: 1.1530 - val_loss: 5.2848 - val_perplexity_raw: 1.1467
# Epoch 23/200
#  - 0s - loss: 2.5348 - perplexity_raw: 1.1461 - val_loss: 5.3049 - val_perplexity_raw: 1.1467
# Epoch 24/200
#  - 0s - loss: 2.4199 - perplexity_raw: 1.1391 - val_loss: 5.3291 - val_perplexity_raw: 1.1467
# Epoch 25/200
#  - 0s - loss: 2.3038 - perplexity_raw: 1.1391 - val_loss: 5.3583 - val_perplexity_raw: 1.1467
# Epoch 26/200
#  - 0s - loss: 2.1918 - perplexity_raw: 1.1252 - val_loss: 5.3870 - val_perplexity_raw: 1.1467
# Epoch 27/200
#  - 0s - loss: 2.0830 - perplexity_raw: 1.1183 - val_loss: 5.4229 - val_perplexity_raw: 1.1257
# Epoch 28/200
#  - 0s - loss: 1.9786 - perplexity_raw: 1.1183 - val_loss: 5.4585 - val_perplexity_raw: 1.1257
# Epoch 29/200
#  - 0s - loss: 1.8772 - perplexity_raw: 1.1113 - val_loss: 5.5007 - val_perplexity_raw: 1.1257
# Epoch 30/200
#  - 0s - loss: 1.7799 - perplexity_raw: 1.1113 - val_loss: 5.5503 - val_perplexity_raw: 1.1257
# Epoch 31/200
#  - 0s - loss: 1.6885 - perplexity_raw: 1.1113 - val_loss: 5.5965 - val_perplexity_raw: 1.1048
# Epoch 32/200
#  - 0s - loss: 1.6030 - perplexity_raw: 1.1113 - val_loss: 5.6428 - val_perplexity_raw: 1.1048
# Epoch 33/200
#  - 0s - loss: 1.5214 - perplexity_raw: 1.1043 - val_loss: 5.6900 - val_perplexity_raw: 1.1048
# Epoch 34/200
#  - 0s - loss: 1.4463 - perplexity_raw: 1.0974 - val_loss: 5.7392 - val_perplexity_raw: 1.1048
# Epoch 35/200
#  - 0s - loss: 1.3716 - perplexity_raw: 1.0974 - val_loss: 5.7903 - val_perplexity_raw: 1.1048
# Epoch 36/200
#  - 0s - loss: 1.3070 - perplexity_raw: 1.1043 - val_loss: 5.8374 - val_perplexity_raw: 1.1048
# Epoch 37/200
#  - 0s - loss: 1.2462 - perplexity_raw: 1.0974 - val_loss: 5.8911 - val_perplexity_raw: 1.1048
# Epoch 38/200
#  - 0s - loss: 1.1856 - perplexity_raw: 1.0904 - val_loss: 5.9348 - val_perplexity_raw: 1.1048
# Epoch 39/200
#  - 0s - loss: 1.1313 - perplexity_raw: 1.0904 - val_loss: 5.9812 - val_perplexity_raw: 1.1048
# Epoch 40/200
#  - 0s - loss: 1.0806 - perplexity_raw: 1.0904 - val_loss: 6.0316 - val_perplexity_raw: 1.1048
# Epoch 41/200
#  - 0s - loss: 1.0335 - perplexity_raw: 1.0904 - val_loss: 6.0835 - val_perplexity_raw: 1.1048
# Epoch 42/200
#  - 0s - loss: 0.9904 - perplexity_raw: 1.0904 - val_loss: 6.1283 - val_perplexity_raw: 1.1048
# Epoch 43/200
#  - 0s - loss: 0.9482 - perplexity_raw: 1.0904 - val_loss: 6.1720 - val_perplexity_raw: 1.1048
# Epoch 44/200
#  - 0s - loss: 0.9091 - perplexity_raw: 1.0904 - val_loss: 6.2097 - val_perplexity_raw: 1.1048
# Epoch 45/200
#  - 0s - loss: 0.8707 - perplexity_raw: 1.0904 - val_loss: 6.2573 - val_perplexity_raw: 1.1048
# Epoch 46/200
#  - 0s - loss: 0.8382 - perplexity_raw: 1.0904 - val_loss: 6.3009 - val_perplexity_raw: 1.1048
# Epoch 47/200
#  - 0s - loss: 0.8057 - perplexity_raw: 1.0904 - val_loss: 6.3427 - val_perplexity_raw: 1.1048
# Epoch 48/200
#  - 0s - loss: 0.7752 - perplexity_raw: 1.0904 - val_loss: 6.3818 - val_perplexity_raw: 1.1048
# Epoch 49/200
#  - 0s - loss: 0.7470 - perplexity_raw: 1.0904 - val_loss: 6.4241 - val_perplexity_raw: 1.1048
# Epoch 50/200
#  - 0s - loss: 0.7222 - perplexity_raw: 1.0904 - val_loss: 6.4614 - val_perplexity_raw: 1.1048
# Epoch 51/200
#  - 0s - loss: 0.6963 - perplexity_raw: 1.0904 - val_loss: 6.4989 - val_perplexity_raw: 1.1048
# Epoch 52/200
#  - 0s - loss: 0.6728 - perplexity_raw: 1.0904 - val_loss: 6.5313 - val_perplexity_raw: 1.1048
# Epoch 53/200
#  - 0s - loss: 0.6523 - perplexity_raw: 1.0904 - val_loss: 6.5662 - val_perplexity_raw: 1.1048
# Epoch 54/200
#  - 0s - loss: 0.6305 - perplexity_raw: 1.0904 - val_loss: 6.6014 - val_perplexity_raw: 1.1048
# Epoch 55/200
#  - 0s - loss: 0.6132 - perplexity_raw: 1.0904 - val_loss: 6.6374 - val_perplexity_raw: 1.1048
# Epoch 56/200
#  - 0s - loss: 0.5953 - perplexity_raw: 1.0904 - val_loss: 6.6648 - val_perplexity_raw: 1.1048
# Epoch 57/200
#  - 0s - loss: 0.5780 - perplexity_raw: 1.0904 - val_loss: 6.6975 - val_perplexity_raw: 1.1048
# Epoch 58/200
#  - 0s - loss: 0.5634 - perplexity_raw: 1.0904 - val_loss: 6.7302 - val_perplexity_raw: 1.1048
# Epoch 59/200
#  - 0s - loss: 0.5470 - perplexity_raw: 1.0904 - val_loss: 6.7608 - val_perplexity_raw: 1.1048
# Epoch 60/200
#  - 0s - loss: 0.5334 - perplexity_raw: 1.0904 - val_loss: 6.7919 - val_perplexity_raw: 1.1048
# Epoch 61/200
#  - 0s - loss: 0.5211 - perplexity_raw: 1.0904 - val_loss: 6.8155 - val_perplexity_raw: 1.1048
# Epoch 62/200
#  - 0s - loss: 0.5093 - perplexity_raw: 1.0904 - val_loss: 6.8383 - val_perplexity_raw: 1.1048
# Epoch 63/200
#  - 0s - loss: 0.4994 - perplexity_raw: 1.0904 - val_loss: 6.8680 - val_perplexity_raw: 1.1048
# Epoch 64/200
#  - 0s - loss: 0.4851 - perplexity_raw: 1.0904 - val_loss: 6.8954 - val_perplexity_raw: 1.1048
# Epoch 65/200
#  - 0s - loss: 0.4774 - perplexity_raw: 1.0904 - val_loss: 6.9154 - val_perplexity_raw: 1.1048
# Epoch 66/200
#  - 0s - loss: 0.4664 - perplexity_raw: 1.0904 - val_loss: 6.9401 - val_perplexity_raw: 1.1048
# Epoch 67/200
#  - 0s - loss: 0.4582 - perplexity_raw: 1.0904 - val_loss: 6.9672 - val_perplexity_raw: 1.1048
# Epoch 68/200
#  - 0s - loss: 0.4504 - perplexity_raw: 1.0904 - val_loss: 6.9898 - val_perplexity_raw: 1.1048
# Epoch 69/200
#  - 0s - loss: 0.4428 - perplexity_raw: 1.0904 - val_loss: 7.0108 - val_perplexity_raw: 1.1048
# Epoch 70/200
#  - 0s - loss: 0.4345 - perplexity_raw: 1.0904 - val_loss: 7.0350 - val_perplexity_raw: 1.1048
# Epoch 71/200
#  - 0s - loss: 0.4284 - perplexity_raw: 1.0904 - val_loss: 7.0592 - val_perplexity_raw: 1.1048
# Epoch 72/200
#  - 0s - loss: 0.4216 - perplexity_raw: 1.0835 - val_loss: 7.0793 - val_perplexity_raw: 1.1048
# Epoch 73/200
#  - 0s - loss: 0.4168 - perplexity_raw: 1.0835 - val_loss: 7.1012 - val_perplexity_raw: 1.1048
# Epoch 74/200
#  - 0s - loss: 0.4096 - perplexity_raw: 1.0835 - val_loss: 7.1201 - val_perplexity_raw: 1.1048
# Epoch 75/200
#  - 0s - loss: 0.4032 - perplexity_raw: 1.0835 - val_loss: 7.1397 - val_perplexity_raw: 1.1048
# Epoch 76/200
#  - 0s - loss: 0.3989 - perplexity_raw: 1.0835 - val_loss: 7.1574 - val_perplexity_raw: 1.1048
# Epoch 77/200
#  - 0s - loss: 0.3955 - perplexity_raw: 1.0835 - val_loss: 7.1726 - val_perplexity_raw: 1.1048
# Epoch 78/200
#  - 0s - loss: 0.3896 - perplexity_raw: 1.0835 - val_loss: 7.1956 - val_perplexity_raw: 1.1048
# Epoch 79/200
#  - 0s - loss: 0.3849 - perplexity_raw: 1.0835 - val_loss: 7.2123 - val_perplexity_raw: 1.1048
# Epoch 80/200
#  - 0s - loss: 0.3817 - perplexity_raw: 1.0835 - val_loss: 7.2336 - val_perplexity_raw: 1.1048
# Epoch 81/200
#  - 0s - loss: 0.3776 - perplexity_raw: 1.0835 - val_loss: 7.2459 - val_perplexity_raw: 1.1048
# Epoch 82/200
#  - 0s - loss: 0.3748 - perplexity_raw: 1.0835 - val_loss: 7.2599 - val_perplexity_raw: 1.1048
# Epoch 83/200
#  - 0s - loss: 0.3716 - perplexity_raw: 1.0835 - val_loss: 7.2782 - val_perplexity_raw: 1.1048
# Epoch 84/200
#  - 0s - loss: 0.3680 - perplexity_raw: 1.0835 - val_loss: 7.2941 - val_perplexity_raw: 1.1048
# Epoch 85/200
#  - 0s - loss: 0.3640 - perplexity_raw: 1.0835 - val_loss: 7.3113 - val_perplexity_raw: 1.1048
# Epoch 86/200
#  - 0s - loss: 0.3631 - perplexity_raw: 1.0835 - val_loss: 7.3294 - val_perplexity_raw: 1.1048
# Epoch 87/200
#  - 0s - loss: 0.3611 - perplexity_raw: 1.0835 - val_loss: 7.3384 - val_perplexity_raw: 1.1048
# Epoch 88/200
#  - 0s - loss: 0.3562 - perplexity_raw: 1.0835 - val_loss: 7.3514 - val_perplexity_raw: 1.1048
# Epoch 89/200
#  - 0s - loss: 0.3551 - perplexity_raw: 1.0835 - val_loss: 7.3652 - val_perplexity_raw: 1.1048
# Epoch 90/200
#  - 0s - loss: 0.3516 - perplexity_raw: 1.0835 - val_loss: 7.3787 - val_perplexity_raw: 1.1048
# Epoch 91/200
#  - 0s - loss: 0.3501 - perplexity_raw: 1.0904 - val_loss: 7.3926 - val_perplexity_raw: 1.1048
# Epoch 92/200
#  - 0s - loss: 0.3468 - perplexity_raw: 1.0835 - val_loss: 7.4104 - val_perplexity_raw: 1.1048
# Epoch 93/200
#  - 0s - loss: 0.3456 - perplexity_raw: 1.0835 - val_loss: 7.4212 - val_perplexity_raw: 1.1048
# Epoch 94/200
#  - 0s - loss: 0.3441 - perplexity_raw: 1.0835 - val_loss: 7.4325 - val_perplexity_raw: 1.1048
# Epoch 95/200
#  - 0s - loss: 0.3411 - perplexity_raw: 1.0835 - val_loss: 7.4435 - val_perplexity_raw: 1.1048
# Epoch 96/200
#  - 0s - loss: 0.3397 - perplexity_raw: 1.0974 - val_loss: 7.4531 - val_perplexity_raw: 1.1257
# Epoch 97/200
#  - 0s - loss: 0.3378 - perplexity_raw: 1.1183 - val_loss: 7.4674 - val_perplexity_raw: 1.1257
# Epoch 98/200
#  - 0s - loss: 0.3365 - perplexity_raw: 1.0974 - val_loss: 7.4773 - val_perplexity_raw: 1.1048
# Epoch 99/200
#  - 0s - loss: 0.3348 - perplexity_raw: 1.0835 - val_loss: 7.4912 - val_perplexity_raw: 1.1048
# Epoch 100/200
#  - 0s - loss: 0.3324 - perplexity_raw: 1.0974 - val_loss: 7.5006 - val_perplexity_raw: 1.1257
# Epoch 101/200
#  - 0s - loss: 0.3316 - perplexity_raw: 1.0835 - val_loss: 7.5112 - val_perplexity_raw: 1.1048
# Epoch 102/200
#  - 0s - loss: 0.3307 - perplexity_raw: 1.0835 - val_loss: 7.5167 - val_perplexity_raw: 1.1048
# Epoch 103/200
#  - 0s - loss: 0.3293 - perplexity_raw: 1.0835 - val_loss: 7.5305 - val_perplexity_raw: 1.1048
# Epoch 104/200
#  - 0s - loss: 0.3280 - perplexity_raw: 1.0835 - val_loss: 7.5369 - val_perplexity_raw: 1.1048
# Epoch 105/200
#  - 0s - loss: 0.3269 - perplexity_raw: 1.0835 - val_loss: 7.5508 - val_perplexity_raw: 1.1048
# Epoch 106/200
#  - 0s - loss: 0.3266 - perplexity_raw: 1.1113 - val_loss: 7.5555 - val_perplexity_raw: 1.1257
# Epoch 107/200
#  - 0s - loss: 0.3246 - perplexity_raw: 1.1183 - val_loss: 7.5681 - val_perplexity_raw: 1.1257
# Epoch 108/200
#  - 0s - loss: 0.3225 - perplexity_raw: 1.0974 - val_loss: 7.5754 - val_perplexity_raw: 1.1048
# Epoch 109/200
#  - 0s - loss: 0.3237 - perplexity_raw: 1.0835 - val_loss: 7.5879 - val_perplexity_raw: 1.1048
# Epoch 110/200
#  - 0s - loss: 0.3201 - perplexity_raw: 1.0835 - val_loss: 7.5949 - val_perplexity_raw: 1.1048
# Epoch 111/200
#  - 0s - loss: 0.3206 - perplexity_raw: 1.0835 - val_loss: 7.6029 - val_perplexity_raw: 1.1048
# Epoch 112/200
#  - 0s - loss: 0.3194 - perplexity_raw: 1.0835 - val_loss: 7.6125 - val_perplexity_raw: 1.1048
# Epoch 113/200
#  - 0s - loss: 0.3187 - perplexity_raw: 1.0835 - val_loss: 7.6179 - val_perplexity_raw: 1.1048
# Epoch 114/200
#  - 0s - loss: 0.3174 - perplexity_raw: 1.0835 - val_loss: 7.6289 - val_perplexity_raw: 1.1048
# Epoch 115/200
#  - 0s - loss: 0.3167 - perplexity_raw: 1.0835 - val_loss: 7.6383 - val_perplexity_raw: 1.1048
# Epoch 116/200
#  - 0s - loss: 0.3160 - perplexity_raw: 1.0835 - val_loss: 7.6467 - val_perplexity_raw: 1.1048
# Epoch 117/200
#  - 0s - loss: 0.3145 - perplexity_raw: 1.0835 - val_loss: 7.6540 - val_perplexity_raw: 1.1048
# Epoch 118/200
#  - 0s - loss: 0.3145 - perplexity_raw: 1.0835 - val_loss: 7.6650 - val_perplexity_raw: 1.1048
# Epoch 119/200
#  - 0s - loss: 0.3134 - perplexity_raw: 1.0835 - val_loss: 7.6702 - val_perplexity_raw: 1.1048
# Epoch 120/200
#  - 0s - loss: 0.3136 - perplexity_raw: 1.0835 - val_loss: 7.6728 - val_perplexity_raw: 1.1048
# Epoch 121/200
#  - 0s - loss: 0.3125 - perplexity_raw: 1.0835 - val_loss: 7.6819 - val_perplexity_raw: 1.1048
# Epoch 122/200
#  - 0s - loss: 0.3124 - perplexity_raw: 1.0835 - val_loss: 7.6916 - val_perplexity_raw: 1.1048
# Epoch 123/200
#  - 0s - loss: 0.3112 - perplexity_raw: 1.0835 - val_loss: 7.6982 - val_perplexity_raw: 1.1048
# Epoch 124/200
#  - 0s - loss: 0.3102 - perplexity_raw: 1.0835 - val_loss: 7.7046 - val_perplexity_raw: 1.1048
# Epoch 125/200
#  - 0s - loss: 0.3083 - perplexity_raw: 1.0835 - val_loss: 7.7128 - val_perplexity_raw: 1.1048
# Epoch 126/200
#  - 0s - loss: 0.3110 - perplexity_raw: 1.0835 - val_loss: 7.7197 - val_perplexity_raw: 1.1048
# Epoch 127/200
#  - 0s - loss: 0.3081 - perplexity_raw: 1.0835 - val_loss: 7.7229 - val_perplexity_raw: 1.1048
# Epoch 128/200
#  - 0s - loss: 0.3090 - perplexity_raw: 1.0835 - val_loss: 7.7305 - val_perplexity_raw: 1.1048
# Epoch 129/200
#  - 0s - loss: 0.3063 - perplexity_raw: 1.0835 - val_loss: 7.7389 - val_perplexity_raw: 1.1048
# Epoch 130/200
#  - 0s - loss: 0.3085 - perplexity_raw: 1.0974 - val_loss: 7.7443 - val_perplexity_raw: 1.1257
# Epoch 131/200
#  - 0s - loss: 0.3065 - perplexity_raw: 1.0974 - val_loss: 7.7509 - val_perplexity_raw: 1.1048
# Epoch 132/200
#  - 0s - loss: 0.3063 - perplexity_raw: 1.1113 - val_loss: 7.7569 - val_perplexity_raw: 1.1257
# Epoch 133/200
#  - 0s - loss: 0.3046 - perplexity_raw: 1.1113 - val_loss: 7.7645 - val_perplexity_raw: 1.1048
# Epoch 134/200
#  - 0s - loss: 0.3057 - perplexity_raw: 1.0835 - val_loss: 7.7750 - val_perplexity_raw: 1.1048
# Epoch 135/200
#  - 0s - loss: 0.3049 - perplexity_raw: 1.0835 - val_loss: 7.7790 - val_perplexity_raw: 1.1048
# Epoch 136/200
#  - 0s - loss: 0.3061 - perplexity_raw: 1.0835 - val_loss: 7.7809 - val_perplexity_raw: 1.1048
# Epoch 137/200
#  - 0s - loss: 0.3035 - perplexity_raw: 1.0835 - val_loss: 7.7881 - val_perplexity_raw: 1.1048
# Epoch 138/200
#  - 0s - loss: 0.3015 - perplexity_raw: 1.0835 - val_loss: 7.7923 - val_perplexity_raw: 1.1048
# Epoch 139/200
#  - 0s - loss: 0.3022 - perplexity_raw: 1.0835 - val_loss: 7.7998 - val_perplexity_raw: 1.1048
# Epoch 140/200
#  - 0s - loss: 0.3021 - perplexity_raw: 1.0835 - val_loss: 7.8062 - val_perplexity_raw: 1.1048
# Epoch 141/200
#  - 0s - loss: 0.3019 - perplexity_raw: 1.0835 - val_loss: 7.8112 - val_perplexity_raw: 1.1048
# Epoch 142/200
#  - 0s - loss: 0.3016 - perplexity_raw: 1.0835 - val_loss: 7.8154 - val_perplexity_raw: 1.1048
# Epoch 143/200
#  - 0s - loss: 0.3016 - perplexity_raw: 1.0974 - val_loss: 7.8189 - val_perplexity_raw: 1.1048
# Epoch 144/200
#  - 0s - loss: 0.2999 - perplexity_raw: 1.0835 - val_loss: 7.8227 - val_perplexity_raw: 1.1048
# Epoch 145/200
#  - 0s - loss: 0.3001 - perplexity_raw: 1.0835 - val_loss: 7.8307 - val_perplexity_raw: 1.1048
# Epoch 146/200
#  - 0s - loss: 0.2991 - perplexity_raw: 1.0835 - val_loss: 7.8365 - val_perplexity_raw: 1.1048
# Epoch 147/200
#  - 0s - loss: 0.3001 - perplexity_raw: 1.0835 - val_loss: 7.8388 - val_perplexity_raw: 1.1048
# Epoch 148/200
#  - 0s - loss: 0.2989 - perplexity_raw: 1.0835 - val_loss: 7.8464 - val_perplexity_raw: 1.1048
# Epoch 149/200
#  - 0s - loss: 0.2987 - perplexity_raw: 1.0835 - val_loss: 7.8558 - val_perplexity_raw: 1.1048
# Epoch 150/200
#  - 0s - loss: 0.2979 - perplexity_raw: 1.0835 - val_loss: 7.8615 - val_perplexity_raw: 1.1048
# Epoch 151/200
#  - 0s - loss: 0.2976 - perplexity_raw: 1.1043 - val_loss: 7.8642 - val_perplexity_raw: 1.1257
# Epoch 152/200
#  - 0s - loss: 0.2968 - perplexity_raw: 1.1183 - val_loss: 7.8697 - val_perplexity_raw: 1.1257
# Epoch 153/200
#  - 0s - loss: 0.2968 - perplexity_raw: 1.1183 - val_loss: 7.8706 - val_perplexity_raw: 1.1257
# Epoch 154/200
#  - 0s - loss: 0.2982 - perplexity_raw: 1.1043 - val_loss: 7.8741 - val_perplexity_raw: 1.1048
# Epoch 155/200
#  - 0s - loss: 0.2971 - perplexity_raw: 1.0835 - val_loss: 7.8863 - val_perplexity_raw: 1.1048
# Epoch 156/200
#  - 0s - loss: 0.2980 - perplexity_raw: 1.0974 - val_loss: 7.8931 - val_perplexity_raw: 1.1257
# Epoch 157/200
#  - 0s - loss: 0.3000 - perplexity_raw: 1.0904 - val_loss: 7.8901 - val_perplexity_raw: 1.1048
# Epoch 158/200
#  - 0s - loss: 0.2957 - perplexity_raw: 1.0835 - val_loss: 7.8947 - val_perplexity_raw: 1.1048
# Epoch 159/200
#  - 0s - loss: 0.2948 - perplexity_raw: 1.1113 - val_loss: 7.9020 - val_perplexity_raw: 1.1048
# Epoch 160/200
#  - 0s - loss: 0.2970 - perplexity_raw: 1.0904 - val_loss: 7.9019 - val_perplexity_raw: 1.1048
# Epoch 161/200
#  - 0s - loss: 0.2948 - perplexity_raw: 1.0835 - val_loss: 7.9133 - val_perplexity_raw: 1.1048
# Epoch 162/200
#  - 0s - loss: 0.2958 - perplexity_raw: 1.0835 - val_loss: 7.9148 - val_perplexity_raw: 1.1048
# Epoch 163/200
#  - 0s - loss: 0.2934 - perplexity_raw: 1.0835 - val_loss: 7.9206 - val_perplexity_raw: 1.1048
# Epoch 164/200
#  - 0s - loss: 0.2948 - perplexity_raw: 1.1043 - val_loss: 7.9275 - val_perplexity_raw: 1.1257
# Epoch 165/200
#  - 0s - loss: 0.2944 - perplexity_raw: 1.1183 - val_loss: 7.9310 - val_perplexity_raw: 1.1257
# Epoch 166/200
#  - 0s - loss: 0.2938 - perplexity_raw: 1.1043 - val_loss: 7.9320 - val_perplexity_raw: 1.1257
# Epoch 167/200
#  - 0s - loss: 0.2962 - perplexity_raw: 1.1113 - val_loss: 7.9296 - val_perplexity_raw: 1.1048
# Epoch 168/200
#  - 0s - loss: 0.2931 - perplexity_raw: 1.0835 - val_loss: 7.9381 - val_perplexity_raw: 1.1048
# Epoch 169/200
#  - 0s - loss: 0.2941 - perplexity_raw: 1.0835 - val_loss: 7.9416 - val_perplexity_raw: 1.1048
# Epoch 170/200
#  - 0s - loss: 0.2932 - perplexity_raw: 1.0835 - val_loss: 7.9429 - val_perplexity_raw: 1.1048
# Epoch 171/200
#  - 0s - loss: 0.2936 - perplexity_raw: 1.0835 - val_loss: 7.9465 - val_perplexity_raw: 1.1048
# Epoch 172/200
#  - 0s - loss: 0.2940 - perplexity_raw: 1.0835 - val_loss: 7.9510 - val_perplexity_raw: 1.1048
# Epoch 173/200
#  - 0s - loss: 0.2917 - perplexity_raw: 1.0835 - val_loss: 7.9568 - val_perplexity_raw: 1.1048
# Epoch 174/200
#  - 0s - loss: 0.2928 - perplexity_raw: 1.0835 - val_loss: 7.9633 - val_perplexity_raw: 1.1048
# Epoch 175/200
#  - 0s - loss: 0.2934 - perplexity_raw: 1.0904 - val_loss: 7.9663 - val_perplexity_raw: 1.1048
# Epoch 176/200
#  - 0s - loss: 0.2925 - perplexity_raw: 1.0835 - val_loss: 7.9690 - val_perplexity_raw: 1.1048
# Epoch 177/200
#  - 0s - loss: 0.2915 - perplexity_raw: 1.0835 - val_loss: 7.9730 - val_perplexity_raw: 1.1048
# Epoch 178/200
#  - 0s - loss: 0.2910 - perplexity_raw: 1.0835 - val_loss: 7.9797 - val_perplexity_raw: 1.1048
# Epoch 179/200
#  - 0s - loss: 0.2913 - perplexity_raw: 1.0835 - val_loss: 7.9859 - val_perplexity_raw: 1.1048
# Epoch 180/200
#  - 0s - loss: 0.2914 - perplexity_raw: 1.0835 - val_loss: 7.9849 - val_perplexity_raw: 1.1048
# Epoch 181/200
#  - 0s - loss: 0.2918 - perplexity_raw: 1.0835 - val_loss: 7.9866 - val_perplexity_raw: 1.1048
# Epoch 182/200
#  - 0s - loss: 0.2917 - perplexity_raw: 1.0835 - val_loss: 7.9870 - val_perplexity_raw: 1.1048
# Epoch 183/200
#  - 0s - loss: 0.2905 - perplexity_raw: 1.0835 - val_loss: 7.9914 - val_perplexity_raw: 1.1048
# Epoch 184/200
#  - 0s - loss: 0.2911 - perplexity_raw: 1.1113 - val_loss: 7.9921 - val_perplexity_raw: 1.1048
# Epoch 185/200
#  - 0s - loss: 0.2915 - perplexity_raw: 1.0835 - val_loss: 7.9950 - val_perplexity_raw: 1.1048
# Epoch 186/200
#  - 0s - loss: 0.2907 - perplexity_raw: 1.0835 - val_loss: 8.0005 - val_perplexity_raw: 1.1048
# Epoch 187/200
#  - 0s - loss: 0.2925 - perplexity_raw: 1.0835 - val_loss: 8.0091 - val_perplexity_raw: 1.1048
# Epoch 188/200
#  - 0s - loss: 0.2906 - perplexity_raw: 1.0835 - val_loss: 8.0111 - val_perplexity_raw: 1.1048
# Epoch 189/200
#  - 0s - loss: 0.2901 - perplexity_raw: 1.0835 - val_loss: 8.0148 - val_perplexity_raw: 1.1048
# Epoch 190/200
#  - 0s - loss: 0.2909 - perplexity_raw: 1.0835 - val_loss: 8.0209 - val_perplexity_raw: 1.1048
# Epoch 191/200
#  - 0s - loss: 0.2889 - perplexity_raw: 1.0835 - val_loss: 8.0238 - val_perplexity_raw: 1.1048
# Epoch 192/200
#  - 0s - loss: 0.2888 - perplexity_raw: 1.0835 - val_loss: 8.0249 - val_perplexity_raw: 1.1048
# Epoch 193/200
#  - 0s - loss: 0.2898 - perplexity_raw: 1.0835 - val_loss: 8.0272 - val_perplexity_raw: 1.1048
# Epoch 194/200
#  - 0s - loss: 0.2900 - perplexity_raw: 1.0835 - val_loss: 8.0296 - val_perplexity_raw: 1.1048
# Epoch 195/200
#  - 0s - loss: 0.2906 - perplexity_raw: 1.0835 - val_loss: 8.0350 - val_perplexity_raw: 1.1048
# Epoch 196/200
#  - 0s - loss: 0.2889 - perplexity_raw: 1.0835 - val_loss: 8.0337 - val_perplexity_raw: 1.1048
# Epoch 197/200
#  - 0s - loss: 0.2901 - perplexity_raw: 1.0835 - val_loss: 8.0377 - val_perplexity_raw: 1.1048
# Epoch 198/200
#  - 0s - loss: 0.2899 - perplexity_raw: 1.1113 - val_loss: 8.0374 - val_perplexity_raw: 1.1257
# Epoch 199/200
#  - 0s - loss: 0.2897 - perplexity_raw: 1.1183 - val_loss: 8.0416 - val_perplexity_raw: 1.1257
# Epoch 200/200
#  - 0s - loss: 0.2891 - perplexity_raw: 1.0904 - val_loss: 8.0433 - val_perplexity_raw: 1.1048

# %%
model = BaseNetwork()
X_train, X_test, y_train, y_test = model.etl(data)
print_shapes()
model.fit(X_train, X_test, y_train, y_test, arch="LSTM_Embedding", epochs=200, hidden_lstm=3)
# Out:
# Shape of X_train: (247, 6)
# Shape of X_test: (82, 6)
# Shape of y_train: (247, 194)
# Shape of y_test: (82, 194)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 6, 64)             12416
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 6, 32)             12416
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 6, 32)             8320
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 6, 32)             8320
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 194)               6402
# =================================================================
# Total params: 56,194
# Trainable params: 56,194
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 247 samples, validate on 82 samples
# Epoch 1/200
#  - 3s - loss: 5.2661 - perplexity_raw: 1.0000 - val_loss: 5.2631 - val_perplexity_raw: 1.0000
# Epoch 2/200
#  - 0s - loss: 5.2553 - perplexity_raw: 1.0000 - val_loss: 5.2563 - val_perplexity_raw: 1.0000
# Epoch 3/200
#  - 0s - loss: 5.2350 - perplexity_raw: 1.0000 - val_loss: 5.2382 - val_perplexity_raw: 1.0000
# Epoch 4/200
#  - 0s - loss: 5.1757 - perplexity_raw: 1.0000 - val_loss: 5.1907 - val_perplexity_raw: 1.0000
# Epoch 5/200
#  - 0s - loss: 5.0008 - perplexity_raw: 1.0000 - val_loss: 5.1517 - val_perplexity_raw: 1.0000
# Epoch 6/200
#  - 0s - loss: 4.7614 - perplexity_raw: 1.0000 - val_loss: 5.2506 - val_perplexity_raw: 1.0000
# Epoch 7/200
#  - 0s - loss: 4.6423 - perplexity_raw: 1.0000 - val_loss: 5.4277 - val_perplexity_raw: 1.0000
# Epoch 8/200
#  - 0s - loss: 4.5834 - perplexity_raw: 1.0000 - val_loss: 5.5354 - val_perplexity_raw: 1.0000
# Epoch 9/200
#  - 0s - loss: 4.5448 - perplexity_raw: 1.0000 - val_loss: 5.6121 - val_perplexity_raw: 1.0000
# Epoch 10/200
#  - 0s - loss: 4.5199 - perplexity_raw: 1.0000 - val_loss: 5.6830 - val_perplexity_raw: 1.0000
# Epoch 11/200
#  - 0s - loss: 4.5071 - perplexity_raw: 1.0000 - val_loss: 5.7483 - val_perplexity_raw: 1.0000
# Epoch 12/200
#  - 0s - loss: 4.4971 - perplexity_raw: 1.0000 - val_loss: 5.8140 - val_perplexity_raw: 1.0000
# Epoch 13/200
#  - 0s - loss: 4.4889 - perplexity_raw: 1.0000 - val_loss: 5.8734 - val_perplexity_raw: 1.0000
# Epoch 14/200
#  - 0s - loss: 4.4848 - perplexity_raw: 1.0000 - val_loss: 5.9286 - val_perplexity_raw: 1.0000
# Epoch 15/200
#  - 0s - loss: 4.4817 - perplexity_raw: 1.0000 - val_loss: 5.9720 - val_perplexity_raw: 1.0000
# Epoch 16/200
#  - 0s - loss: 4.4785 - perplexity_raw: 1.0000 - val_loss: 6.0100 - val_perplexity_raw: 1.0000
# Epoch 17/200
#  - 0s - loss: 4.4756 - perplexity_raw: 1.0000 - val_loss: 6.0502 - val_perplexity_raw: 1.0000
# Epoch 18/200
#  - 0s - loss: 4.4743 - perplexity_raw: 1.0000 - val_loss: 6.0850 - val_perplexity_raw: 1.0000
# Epoch 19/200
#  - 0s - loss: 4.4729 - perplexity_raw: 1.0000 - val_loss: 6.1168 - val_perplexity_raw: 1.0000
# Epoch 20/200
#  - 0s - loss: 4.4708 - perplexity_raw: 1.0000 - val_loss: 6.1444 - val_perplexity_raw: 1.0000
# Epoch 21/200
#  - 0s - loss: 4.4696 - perplexity_raw: 1.0000 - val_loss: 6.1783 - val_perplexity_raw: 1.0000
# Epoch 22/200
#  - 0s - loss: 4.4674 - perplexity_raw: 1.0000 - val_loss: 6.2075 - val_perplexity_raw: 1.0000
# Epoch 23/200
#  - 0s - loss: 4.4674 - perplexity_raw: 1.0000 - val_loss: 6.2270 - val_perplexity_raw: 1.0000
# Epoch 24/200
#  - 0s - loss: 4.4651 - perplexity_raw: 1.0000 - val_loss: 6.2562 - val_perplexity_raw: 1.0000
# Epoch 25/200
#  - 0s - loss: 4.4640 - perplexity_raw: 1.0000 - val_loss: 6.2733 - val_perplexity_raw: 1.0000
# Epoch 26/200
#  - 0s - loss: 4.4630 - perplexity_raw: 1.0000 - val_loss: 6.2762 - val_perplexity_raw: 1.0000
# Epoch 27/200
#  - 0s - loss: 4.4602 - perplexity_raw: 1.0000 - val_loss: 6.2869 - val_perplexity_raw: 1.0000
# Epoch 28/200
#  - 0s - loss: 4.4548 - perplexity_raw: 1.0000 - val_loss: 6.2685 - val_perplexity_raw: 1.0000
# Epoch 29/200
#  - 0s - loss: 4.4475 - perplexity_raw: 1.0000 - val_loss: 6.1818 - val_perplexity_raw: 1.0000
# Epoch 30/200
#  - 0s - loss: 4.4328 - perplexity_raw: 1.0000 - val_loss: 6.0320 - val_perplexity_raw: 1.0000
# Epoch 31/200
#  - 0s - loss: 4.4173 - perplexity_raw: 1.0000 - val_loss: 5.9422 - val_perplexity_raw: 1.0000
# Epoch 32/200
#  - 0s - loss: 4.4053 - perplexity_raw: 1.0000 - val_loss: 6.0238 - val_perplexity_raw: 1.0000
# Epoch 33/200
#  - 0s - loss: 4.3893 - perplexity_raw: 1.0000 - val_loss: 5.8519 - val_perplexity_raw: 1.0000
# Epoch 34/200
#  - 0s - loss: 4.3762 - perplexity_raw: 1.0000 - val_loss: 5.9081 - val_perplexity_raw: 1.0000
# Epoch 35/200
#  - 0s - loss: 4.3667 - perplexity_raw: 1.0000 - val_loss: 5.8015 - val_perplexity_raw: 1.0000
# Epoch 36/200
#  - 0s - loss: 4.3505 - perplexity_raw: 1.0000 - val_loss: 5.8458 - val_perplexity_raw: 1.0000
# Epoch 37/200
#  - 0s - loss: 4.3384 - perplexity_raw: 1.0000 - val_loss: 5.8045 - val_perplexity_raw: 1.0000
# Epoch 38/200
#  - 0s - loss: 4.3277 - perplexity_raw: 1.0000 - val_loss: 5.8254 - val_perplexity_raw: 1.0000
# Epoch 39/200
#  - 0s - loss: 4.3141 - perplexity_raw: 1.0000 - val_loss: 5.7864 - val_perplexity_raw: 1.0000
# Epoch 40/200
#  - 0s - loss: 4.3010 - perplexity_raw: 1.0000 - val_loss: 5.8020 - val_perplexity_raw: 1.0000
# Epoch 41/200
#  - 0s - loss: 4.2879 - perplexity_raw: 1.0000 - val_loss: 5.7995 - val_perplexity_raw: 1.0000
# Epoch 42/200
#  - 0s - loss: 4.2762 - perplexity_raw: 1.0000 - val_loss: 5.7036 - val_perplexity_raw: 1.0000
# Epoch 43/200
#  - 0s - loss: 4.2615 - perplexity_raw: 1.0000 - val_loss: 5.7670 - val_perplexity_raw: 1.0000
# Epoch 44/200
#  - 0s - loss: 4.2484 - perplexity_raw: 1.0000 - val_loss: 5.7601 - val_perplexity_raw: 1.0000
# Epoch 45/200
#  - 0s - loss: 4.2381 - perplexity_raw: 1.1670 - val_loss: 5.7515 - val_perplexity_raw: 1.1886
# Epoch 46/200
#  - 0s - loss: 4.2192 - perplexity_raw: 1.1878 - val_loss: 5.6948 - val_perplexity_raw: 1.1467
# Epoch 47/200
#  - 0s - loss: 4.2078 - perplexity_raw: 1.0209 - val_loss: 5.7613 - val_perplexity_raw: 1.1676
# Epoch 48/200
#  - 0s - loss: 4.1918 - perplexity_raw: 1.1530 - val_loss: 5.6890 - val_perplexity_raw: 1.1676
# Epoch 49/200
#  - 0s - loss: 4.1735 - perplexity_raw: 1.1948 - val_loss: 5.7308 - val_perplexity_raw: 1.1676
# Epoch 50/200
#  - 0s - loss: 4.1611 - perplexity_raw: 1.1670 - val_loss: 5.7276 - val_perplexity_raw: 1.1467
# Epoch 51/200
#  - 0s - loss: 4.1452 - perplexity_raw: 1.2017 - val_loss: 5.7653 - val_perplexity_raw: 1.1886
# Epoch 52/200
#  - 0s - loss: 4.1276 - perplexity_raw: 1.1670 - val_loss: 5.6731 - val_perplexity_raw: 1.0000
# Epoch 53/200
#  - 0s - loss: 4.1120 - perplexity_raw: 1.0974 - val_loss: 5.8232 - val_perplexity_raw: 1.2095
# Epoch 54/200
#  - 0s - loss: 4.0975 - perplexity_raw: 1.0487 - val_loss: 5.7732 - val_perplexity_raw: 1.0000
# Epoch 55/200
#  - 0s - loss: 4.0782 - perplexity_raw: 1.0139 - val_loss: 5.7889 - val_perplexity_raw: 1.0000
# Epoch 56/200
#  - 0s - loss: 4.0635 - perplexity_raw: 1.0139 - val_loss: 5.7397 - val_perplexity_raw: 1.0000
# Epoch 57/200
#  - 0s - loss: 4.0499 - perplexity_raw: 1.0139 - val_loss: 5.8206 - val_perplexity_raw: 1.0000
# Epoch 58/200
#  - 0s - loss: 4.0316 - perplexity_raw: 1.0000 - val_loss: 5.8234 - val_perplexity_raw: 1.0000
# Epoch 59/200
#  - 0s - loss: 4.0177 - perplexity_raw: 1.0278 - val_loss: 5.8088 - val_perplexity_raw: 1.0000
# Epoch 60/200
#  - 0s - loss: 4.0032 - perplexity_raw: 1.0000 - val_loss: 5.8608 - val_perplexity_raw: 1.0000
# Epoch 61/200
#  - 0s - loss: 3.9868 - perplexity_raw: 1.0000 - val_loss: 5.9067 - val_perplexity_raw: 1.0000
# Epoch 62/200
#  - 0s - loss: 3.9721 - perplexity_raw: 1.0000 - val_loss: 5.9351 - val_perplexity_raw: 1.0000
# Epoch 63/200
#  - 0s - loss: 3.9585 - perplexity_raw: 1.0070 - val_loss: 5.9099 - val_perplexity_raw: 1.0000
# Epoch 64/200
#  - 0s - loss: 3.9457 - perplexity_raw: 1.0070 - val_loss: 5.9461 - val_perplexity_raw: 1.0000
# Epoch 65/200
#  - 0s - loss: 3.9243 - perplexity_raw: 1.0000 - val_loss: 5.9654 - val_perplexity_raw: 1.0000
# Epoch 66/200
#  - 0s - loss: 3.9081 - perplexity_raw: 1.0000 - val_loss: 6.0127 - val_perplexity_raw: 1.0000
# Epoch 67/200
#  - 0s - loss: 3.8949 - perplexity_raw: 1.0000 - val_loss: 6.0357 - val_perplexity_raw: 1.0000
# Epoch 68/200
#  - 0s - loss: 3.8753 - perplexity_raw: 1.0070 - val_loss: 6.0949 - val_perplexity_raw: 1.0000
# Epoch 69/200
#  - 0s - loss: 3.8594 - perplexity_raw: 1.0139 - val_loss: 6.0525 - val_perplexity_raw: 1.0210
# Epoch 70/200
#  - 0s - loss: 3.8459 - perplexity_raw: 1.0070 - val_loss: 6.1439 - val_perplexity_raw: 1.0419
# Epoch 71/200
#  - 0s - loss: 3.8292 - perplexity_raw: 1.0070 - val_loss: 6.1359 - val_perplexity_raw: 1.0419
# Epoch 72/200
#  - 0s - loss: 3.8105 - perplexity_raw: 1.0070 - val_loss: 6.1528 - val_perplexity_raw: 1.0419
# Epoch 73/200
#  - 0s - loss: 3.7957 - perplexity_raw: 1.0070 - val_loss: 6.2288 - val_perplexity_raw: 1.0419
# Epoch 74/200
#  - 0s - loss: 3.7805 - perplexity_raw: 1.0139 - val_loss: 6.1947 - val_perplexity_raw: 1.0419
# Epoch 75/200
#  - 0s - loss: 3.7595 - perplexity_raw: 1.0070 - val_loss: 6.2578 - val_perplexity_raw: 1.0419
# Epoch 76/200
#  - 0s - loss: 3.7436 - perplexity_raw: 1.0070 - val_loss: 6.2138 - val_perplexity_raw: 1.0419
# Epoch 77/200
#  - 0s - loss: 3.7284 - perplexity_raw: 1.0070 - val_loss: 6.2202 - val_perplexity_raw: 1.0419
# Epoch 78/200
#  - 0s - loss: 3.7130 - perplexity_raw: 1.0070 - val_loss: 6.3432 - val_perplexity_raw: 1.0419
# Epoch 79/200
#  - 0s - loss: 3.6961 - perplexity_raw: 1.0070 - val_loss: 6.3397 - val_perplexity_raw: 1.0210
# Epoch 80/200
#  - 0s - loss: 3.6794 - perplexity_raw: 1.0070 - val_loss: 6.3568 - val_perplexity_raw: 1.0210
# Epoch 81/200
#  - 0s - loss: 3.6592 - perplexity_raw: 1.0070 - val_loss: 6.3466 - val_perplexity_raw: 1.0210
# Epoch 82/200
#  - 0s - loss: 3.6453 - perplexity_raw: 1.0070 - val_loss: 6.3778 - val_perplexity_raw: 1.0000
# Epoch 83/200
#  - 0s - loss: 3.6326 - perplexity_raw: 1.0000 - val_loss: 6.3868 - val_perplexity_raw: 1.0000
# Epoch 84/200
#  - 0s - loss: 3.6154 - perplexity_raw: 1.0000 - val_loss: 6.3948 - val_perplexity_raw: 1.0000
# Epoch 85/200
#  - 0s - loss: 3.6066 - perplexity_raw: 1.0000 - val_loss: 6.4243 - val_perplexity_raw: 1.0210
# Epoch 86/200
#  - 0s - loss: 3.5840 - perplexity_raw: 1.0070 - val_loss: 6.4929 - val_perplexity_raw: 1.0000
# Epoch 87/200
#  - 0s - loss: 3.5713 - perplexity_raw: 1.0000 - val_loss: 6.4857 - val_perplexity_raw: 1.0000
# Epoch 88/200
#  - 0s - loss: 3.5591 - perplexity_raw: 1.0000 - val_loss: 6.5210 - val_perplexity_raw: 1.0000
# Epoch 89/200
#  - 0s - loss: 3.5410 - perplexity_raw: 1.0070 - val_loss: 6.4809 - val_perplexity_raw: 1.0210
# Epoch 90/200
#  - 0s - loss: 3.5333 - perplexity_raw: 1.0000 - val_loss: 6.4730 - val_perplexity_raw: 1.0000
# Epoch 91/200
#  - 0s - loss: 3.5273 - perplexity_raw: 1.0000 - val_loss: 6.4161 - val_perplexity_raw: 1.0000
# Epoch 92/200
#  - 0s - loss: 3.5152 - perplexity_raw: 1.0000 - val_loss: 6.5677 - val_perplexity_raw: 1.0000
# Epoch 93/200
#  - 0s - loss: 3.5009 - perplexity_raw: 1.0348 - val_loss: 6.5468 - val_perplexity_raw: 1.0000
# Epoch 94/200
#  - 0s - loss: 3.4755 - perplexity_raw: 1.0000 - val_loss: 6.5182 - val_perplexity_raw: 1.0000
# Epoch 95/200
#  - 0s - loss: 3.4504 - perplexity_raw: 1.0000 - val_loss: 6.5681 - val_perplexity_raw: 1.0000
# Epoch 96/200
#  - 0s - loss: 3.4378 - perplexity_raw: 1.0000 - val_loss: 6.5547 - val_perplexity_raw: 1.0000
# Epoch 97/200
#  - 0s - loss: 3.4216 - perplexity_raw: 1.0000 - val_loss: 6.5997 - val_perplexity_raw: 1.0210
# Epoch 98/200
#  - 0s - loss: 3.4084 - perplexity_raw: 1.0070 - val_loss: 6.6091 - val_perplexity_raw: 1.0210
# Epoch 99/200
#  - 0s - loss: 3.3926 - perplexity_raw: 1.0070 - val_loss: 6.5800 - val_perplexity_raw: 1.0000
# Epoch 100/200
#  - 0s - loss: 3.3819 - perplexity_raw: 1.0000 - val_loss: 6.6610 - val_perplexity_raw: 1.0000
# Epoch 101/200
#  - 0s - loss: 3.3709 - perplexity_raw: 1.0000 - val_loss: 6.6334 - val_perplexity_raw: 1.0210
# Epoch 102/200
#  - 0s - loss: 3.3511 - perplexity_raw: 1.0000 - val_loss: 6.6638 - val_perplexity_raw: 1.0000
# Epoch 103/200
#  - 0s - loss: 3.3369 - perplexity_raw: 1.0000 - val_loss: 6.6899 - val_perplexity_raw: 1.0000
# Epoch 104/200
#  - 0s - loss: 3.3282 - perplexity_raw: 1.0000 - val_loss: 6.6900 - val_perplexity_raw: 1.0000
# Epoch 105/200
#  - 0s - loss: 3.3117 - perplexity_raw: 1.0000 - val_loss: 6.6664 - val_perplexity_raw: 1.0000
# Epoch 106/200
#  - 0s - loss: 3.2975 - perplexity_raw: 1.0000 - val_loss: 6.6914 - val_perplexity_raw: 1.0000
# Epoch 107/200
#  - 0s - loss: 3.2829 - perplexity_raw: 1.0000 - val_loss: 6.7245 - val_perplexity_raw: 1.0000
# Epoch 108/200
#  - 0s - loss: 3.2695 - perplexity_raw: 1.0000 - val_loss: 6.7442 - val_perplexity_raw: 1.0210
# Epoch 109/200
#  - 0s - loss: 3.2585 - perplexity_raw: 1.0070 - val_loss: 6.7107 - val_perplexity_raw: 1.0000
# Epoch 110/200
#  - 0s - loss: 3.2438 - perplexity_raw: 1.0000 - val_loss: 6.7557 - val_perplexity_raw: 1.0000
# Epoch 111/200
#  - 0s - loss: 3.2334 - perplexity_raw: 1.0000 - val_loss: 6.7427 - val_perplexity_raw: 1.0000
# Epoch 112/200
#  - 0s - loss: 3.2232 - perplexity_raw: 1.0000 - val_loss: 6.7503 - val_perplexity_raw: 1.0000
# Epoch 113/200
#  - 0s - loss: 3.2116 - perplexity_raw: 1.0000 - val_loss: 6.7298 - val_perplexity_raw: 1.0210
# Epoch 114/200
#  - 0s - loss: 3.2063 - perplexity_raw: 1.0000 - val_loss: 6.8057 - val_perplexity_raw: 1.0000
# Epoch 115/200
#  - 0s - loss: 3.1919 - perplexity_raw: 1.0000 - val_loss: 6.7975 - val_perplexity_raw: 1.0000
# Epoch 116/200
#  - 0s - loss: 3.1778 - perplexity_raw: 1.0070 - val_loss: 6.7623 - val_perplexity_raw: 1.0000
# Epoch 117/200
#  - 0s - loss: 3.1672 - perplexity_raw: 1.0000 - val_loss: 6.8357 - val_perplexity_raw: 1.0000
# Epoch 118/200
#  - 0s - loss: 3.1710 - perplexity_raw: 1.0000 - val_loss: 6.7191 - val_perplexity_raw: 1.0210
# Epoch 119/200
#  - 0s - loss: 3.1521 - perplexity_raw: 1.0000 - val_loss: 6.7988 - val_perplexity_raw: 1.0210
# Epoch 120/200
#  - 0s - loss: 3.1387 - perplexity_raw: 1.0000 - val_loss: 6.7684 - val_perplexity_raw: 1.0000
# Epoch 121/200
#  - 0s - loss: 3.1214 - perplexity_raw: 1.0000 - val_loss: 6.8140 - val_perplexity_raw: 1.0210
# Epoch 122/200
#  - 0s - loss: 3.1129 - perplexity_raw: 1.0000 - val_loss: 6.8228 - val_perplexity_raw: 1.0210
# Epoch 123/200
#  - 0s - loss: 3.0962 - perplexity_raw: 1.0070 - val_loss: 6.8153 - val_perplexity_raw: 1.0210
# Epoch 124/200
#  - 0s - loss: 3.0860 - perplexity_raw: 1.0070 - val_loss: 6.8553 - val_perplexity_raw: 1.0000
# Epoch 125/200
#  - 0s - loss: 3.0717 - perplexity_raw: 1.0070 - val_loss: 6.8344 - val_perplexity_raw: 1.0210
# Epoch 126/200
#  - 0s - loss: 3.0642 - perplexity_raw: 1.0000 - val_loss: 6.9029 - val_perplexity_raw: 1.0000
# Epoch 127/200
#  - 0s - loss: 3.0524 - perplexity_raw: 1.0000 - val_loss: 6.8604 - val_perplexity_raw: 1.0000
# Epoch 128/200
#  - 0s - loss: 3.0425 - perplexity_raw: 1.0000 - val_loss: 6.9060 - val_perplexity_raw: 1.0000
# Epoch 129/200
#  - 0s - loss: 3.0392 - perplexity_raw: 1.0070 - val_loss: 6.9342 - val_perplexity_raw: 1.0000
# Epoch 130/200
#  - 0s - loss: 3.0321 - perplexity_raw: 1.0000 - val_loss: 6.9365 - val_perplexity_raw: 1.0000
# Epoch 131/200
#  - 0s - loss: 3.0114 - perplexity_raw: 1.0139 - val_loss: 6.9321 - val_perplexity_raw: 1.0210
# Epoch 132/200
#  - 0s - loss: 3.0078 - perplexity_raw: 1.0278 - val_loss: 6.9135 - val_perplexity_raw: 1.0210
# Epoch 133/200
#  - 0s - loss: 2.9897 - perplexity_raw: 1.0000 - val_loss: 6.9347 - val_perplexity_raw: 1.0210
# Epoch 134/200
#  - 0s - loss: 2.9786 - perplexity_raw: 1.0000 - val_loss: 6.9425 - val_perplexity_raw: 1.0419
# Epoch 135/200
#  - 0s - loss: 2.9713 - perplexity_raw: 1.0139 - val_loss: 6.9644 - val_perplexity_raw: 1.0210
# Epoch 136/200
#  - 0s - loss: 2.9598 - perplexity_raw: 1.0000 - val_loss: 6.9467 - val_perplexity_raw: 1.0210
# Epoch 137/200
#  - 0s - loss: 2.9492 - perplexity_raw: 1.0209 - val_loss: 6.9781 - val_perplexity_raw: 1.0000
# Epoch 138/200
#  - 0s - loss: 2.9368 - perplexity_raw: 1.0070 - val_loss: 6.9817 - val_perplexity_raw: 1.0000
# Epoch 139/200
#  - 0s - loss: 2.9249 - perplexity_raw: 1.0070 - val_loss: 6.9656 - val_perplexity_raw: 1.0210
# Epoch 140/200
#  - 0s - loss: 2.9142 - perplexity_raw: 1.0000 - val_loss: 6.9798 - val_perplexity_raw: 1.0210
# Epoch 141/200
#  - 0s - loss: 2.9031 - perplexity_raw: 1.0070 - val_loss: 6.9718 - val_perplexity_raw: 1.0210
# Epoch 142/200
#  - 0s - loss: 2.8910 - perplexity_raw: 1.0278 - val_loss: 6.9648 - val_perplexity_raw: 1.0210
# Epoch 143/200
#  - 0s - loss: 2.8861 - perplexity_raw: 1.0000 - val_loss: 7.0250 - val_perplexity_raw: 1.0210
# Epoch 144/200
#  - 0s - loss: 2.8741 - perplexity_raw: 1.0209 - val_loss: 6.9901 - val_perplexity_raw: 1.0210
# Epoch 145/200
#  - 0s - loss: 2.8675 - perplexity_raw: 1.0278 - val_loss: 7.0185 - val_perplexity_raw: 1.0210
# Epoch 146/200
#  - 0s - loss: 2.8544 - perplexity_raw: 1.0139 - val_loss: 6.9692 - val_perplexity_raw: 1.0629
# Epoch 147/200
#  - 0s - loss: 2.8525 - perplexity_raw: 1.0348 - val_loss: 7.0409 - val_perplexity_raw: 1.0000
# Epoch 148/200
#  - 0s - loss: 2.8413 - perplexity_raw: 1.0070 - val_loss: 6.9918 - val_perplexity_raw: 1.0210
# Epoch 149/200
#  - 0s - loss: 2.8294 - perplexity_raw: 1.0278 - val_loss: 6.9892 - val_perplexity_raw: 1.0000
# Epoch 150/200
#  - 0s - loss: 2.8193 - perplexity_raw: 1.0209 - val_loss: 7.0131 - val_perplexity_raw: 1.0000
# Epoch 151/200
#  - 0s - loss: 2.8054 - perplexity_raw: 1.0070 - val_loss: 7.0570 - val_perplexity_raw: 1.0210
# Epoch 152/200
#  - 0s - loss: 2.7946 - perplexity_raw: 1.0000 - val_loss: 7.0292 - val_perplexity_raw: 1.0000
# Epoch 153/200
#  - 0s - loss: 2.7775 - perplexity_raw: 1.0070 - val_loss: 7.0512 - val_perplexity_raw: 1.0000
# Epoch 154/200
#  - 0s - loss: 2.7690 - perplexity_raw: 1.0000 - val_loss: 7.0624 - val_perplexity_raw: 1.0210
# Epoch 155/200
#  - 0s - loss: 2.7571 - perplexity_raw: 1.0139 - val_loss: 7.0468 - val_perplexity_raw: 1.0000
# Epoch 156/200
#  - 0s - loss: 2.7481 - perplexity_raw: 1.0139 - val_loss: 7.0625 - val_perplexity_raw: 1.0210
# Epoch 157/200
#  - 0s - loss: 2.7380 - perplexity_raw: 1.1322 - val_loss: 7.0763 - val_perplexity_raw: 1.0838
# Epoch 158/200
#  - 0s - loss: 2.7284 - perplexity_raw: 1.0974 - val_loss: 7.0604 - val_perplexity_raw: 1.0210
# Epoch 159/200
#  - 0s - loss: 2.7256 - perplexity_raw: 1.0278 - val_loss: 7.0727 - val_perplexity_raw: 1.0000
# Epoch 160/200
#  - 0s - loss: 2.7113 - perplexity_raw: 1.0348 - val_loss: 7.0856 - val_perplexity_raw: 1.1048
# Epoch 161/200
#  - 0s - loss: 2.7016 - perplexity_raw: 1.1322 - val_loss: 7.0609 - val_perplexity_raw: 1.1048
# Epoch 162/200
#  - 0s - loss: 2.6959 - perplexity_raw: 1.0904 - val_loss: 7.0700 - val_perplexity_raw: 1.0000
# Epoch 163/200
#  - 0s - loss: 2.6821 - perplexity_raw: 1.0070 - val_loss: 7.1304 - val_perplexity_raw: 1.0838
# Epoch 164/200
#  - 0s - loss: 2.6724 - perplexity_raw: 1.1113 - val_loss: 7.0729 - val_perplexity_raw: 1.0000
# Epoch 165/200
#  - 0s - loss: 2.6666 - perplexity_raw: 1.0487 - val_loss: 7.1507 - val_perplexity_raw: 1.1257
# Epoch 166/200
#  - 0s - loss: 2.6637 - perplexity_raw: 1.1113 - val_loss: 7.0812 - val_perplexity_raw: 1.0000
# Epoch 167/200
#  - 0s - loss: 2.6592 - perplexity_raw: 1.0209 - val_loss: 7.1543 - val_perplexity_raw: 1.0000
# Epoch 168/200
#  - 0s - loss: 2.6452 - perplexity_raw: 1.0000 - val_loss: 7.1279 - val_perplexity_raw: 1.0838
# Epoch 169/200
#  - 0s - loss: 2.6372 - perplexity_raw: 1.0139 - val_loss: 7.1568 - val_perplexity_raw: 1.0000
# Epoch 170/200
#  - 0s - loss: 2.6296 - perplexity_raw: 1.0487 - val_loss: 7.1358 - val_perplexity_raw: 1.0210
# Epoch 171/200
#  - 0s - loss: 2.6135 - perplexity_raw: 1.0835 - val_loss: 7.1417 - val_perplexity_raw: 1.1676
# Epoch 172/200
#  - 0s - loss: 2.6049 - perplexity_raw: 1.0417 - val_loss: 7.1732 - val_perplexity_raw: 1.0000
# Epoch 173/200
#  - 0s - loss: 2.5949 - perplexity_raw: 1.0557 - val_loss: 7.1590 - val_perplexity_raw: 1.0629
# Epoch 174/200
#  - 0s - loss: 2.5866 - perplexity_raw: 1.1183 - val_loss: 7.1489 - val_perplexity_raw: 1.1676
# Epoch 175/200
#  - 0s - loss: 2.5906 - perplexity_raw: 1.0557 - val_loss: 7.2050 - val_perplexity_raw: 1.1048
# Epoch 176/200
#  - 0s - loss: 2.5795 - perplexity_raw: 1.1530 - val_loss: 7.2095 - val_perplexity_raw: 1.0419
# Epoch 177/200
#  - 0s - loss: 2.5748 - perplexity_raw: 1.1322 - val_loss: 7.2068 - val_perplexity_raw: 1.1467
# Epoch 178/200
#  - 0s - loss: 2.5770 - perplexity_raw: 1.1391 - val_loss: 7.1374 - val_perplexity_raw: 1.0629
# Epoch 179/200
#  - 0s - loss: 2.5489 - perplexity_raw: 1.1878 - val_loss: 7.2631 - val_perplexity_raw: 1.1676
# Epoch 180/200
#  - 0s - loss: 2.5336 - perplexity_raw: 1.1670 - val_loss: 7.1293 - val_perplexity_raw: 1.0210
# Epoch 181/200
#  - 0s - loss: 2.5251 - perplexity_raw: 1.0417 - val_loss: 7.1963 - val_perplexity_raw: 1.0210
# Epoch 182/200
#  - 0s - loss: 2.5132 - perplexity_raw: 1.0974 - val_loss: 7.1667 - val_perplexity_raw: 1.0210
# Epoch 183/200
#  - 0s - loss: 2.5010 - perplexity_raw: 1.0417 - val_loss: 7.1920 - val_perplexity_raw: 1.0210
# Epoch 184/200
#  - 0s - loss: 2.4895 - perplexity_raw: 1.0835 - val_loss: 7.1912 - val_perplexity_raw: 1.1257
# Epoch 185/200
#  - 0s - loss: 2.4807 - perplexity_raw: 1.1391 - val_loss: 7.1953 - val_perplexity_raw: 1.1257
# Epoch 186/200
#  - 0s - loss: 2.4696 - perplexity_raw: 1.1530 - val_loss: 7.2120 - val_perplexity_raw: 1.1257
# Epoch 187/200
#  - 0s - loss: 2.4639 - perplexity_raw: 1.1600 - val_loss: 7.1798 - val_perplexity_raw: 1.1048
# Epoch 188/200
#  - 0s - loss: 2.4502 - perplexity_raw: 1.1322 - val_loss: 7.1875 - val_perplexity_raw: 1.1048
# Epoch 189/200
#  - 0s - loss: 2.4433 - perplexity_raw: 1.1322 - val_loss: 7.1911 - val_perplexity_raw: 1.1048
# Epoch 190/200
#  - 0s - loss: 2.4348 - perplexity_raw: 1.1322 - val_loss: 7.1933 - val_perplexity_raw: 1.1048
# Epoch 191/200
#  - 0s - loss: 2.4268 - perplexity_raw: 1.1252 - val_loss: 7.1928 - val_perplexity_raw: 1.1048
# Epoch 192/200
#  - 0s - loss: 2.4194 - perplexity_raw: 1.1252 - val_loss: 7.1918 - val_perplexity_raw: 1.1048
# Epoch 193/200
#  - 0s - loss: 2.4073 - perplexity_raw: 1.1252 - val_loss: 7.1914 - val_perplexity_raw: 1.1048
# Epoch 194/200
#  - 0s - loss: 2.3984 - perplexity_raw: 1.1252 - val_loss: 7.1958 - val_perplexity_raw: 1.1048
# Epoch 195/200
#  - 0s - loss: 2.3898 - perplexity_raw: 1.1252 - val_loss: 7.2107 - val_perplexity_raw: 1.1048
# Epoch 196/200
#  - 0s - loss: 2.3794 - perplexity_raw: 1.1252 - val_loss: 7.1875 - val_perplexity_raw: 1.1048
# Epoch 197/200
#  - 0s - loss: 2.3712 - perplexity_raw: 1.1252 - val_loss: 7.2013 - val_perplexity_raw: 1.1048
# Epoch 198/200
#  - 0s - loss: 2.3619 - perplexity_raw: 1.1252 - val_loss: 7.2170 - val_perplexity_raw: 1.1048
# Epoch 199/200
#  - 0s - loss: 2.3532 - perplexity_raw: 1.1252 - val_loss: 7.2211 - val_perplexity_raw: 1.1048
# Epoch 200/200
#  - 0s - loss: 2.3460 - perplexity_raw: 1.1252 - val_loss: 7.2220 - val_perplexity_raw: 1.1048
